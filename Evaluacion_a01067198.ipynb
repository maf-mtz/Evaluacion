# %% [markdown]
# <a href="https://colab.research.google.com/github/maf-mtz/Evaluacion/blob/main/Evaluacion_a01067198.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ACTIVIDAD 5. Evaluación**
# ## María Fernanda Martínez Ríos
# A01067198

# %% [markdown]
# # **Etapa 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Eliminar nulos**

# %% [markdown]
# ### California

# %%
calif = pd.read_csv('California_EUA (1).csv',encoding='unicode_escape')

# %%
calif.head()
# Out:
#     ï»¿id                        listing_url     scrape_id last_scraped  \
# 0   958.0   https://www.airbnb.com/rooms/958  2.020000e+13   06/03/2023
# 1  5858.0  https://www.airbnb.com/rooms/5858  2.020000e+13   06/03/2023
# 2  8142.0  https://www.airbnb.com/rooms/8142  2.020000e+13   06/03/2023
# 3  8339.0  https://www.airbnb.com/rooms/8339  2.020000e+13   06/03/2023
# 4  8739.0  https://www.airbnb.com/rooms/8739  2.020000e+13   06/03/2023
#
#         source                                               name  \
# 0  city scrape              Bright, Modern Garden Unit - 1BR/1BTH
# 1  city scrape                                 Creative Sanctuary
# 2  city scrape  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 3  city scrape                    Historic Alamo Square Victorian
# 4  city scrape                Mission Sunshine, with Private Bath
#
#                                          description  \
# 0  Our bright garden unit overlooks a lovely back...
# ...

# %%
calif.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6936 entries, 0 to 6935
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ï»¿id                                         6936 non-null   float64
#  1   listing_url                                   6936 non-null   object
#  2   scrape_id                                     6936 non-null   float64
#  3   last_scraped                                  6936 non-null   object
#  4   source                                        6936 non-null   object
#  5   name                                          6936 non-null   object
#  6   description                                   6889 non-null   object
#  7   neighborhood_overview                         4850 non-null   object
#  8   picture_url                                   6936 non-null   object
# ...

# %%
calif.isnull().sum()
# Out:
# ï»¿id                                              0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1325
# Length: 75, dtype: int64

# %%
numericas=calif.select_dtypes(include=['float']).columns
calif[numericas]=calif[numericas].fillna(calif[numericas].mean())
categoricas=calif.select_dtypes(include=['object']).columns
calif[categoricas]=calif[categoricas].fillna(value='Sin registro')

# %%
calif.isnull().sum()
# Out:
# ï»¿id                                           0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %% [markdown]
# ### España

# %%
esp = pd.read_csv('Girona_Espana.csv', encoding='unicode_escape')

# %%
esp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19655 entries, 0 to 19654
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            19655 non-null  float64
#  1   listing_url                                   19655 non-null  object
#  2   scrape_id                                     19655 non-null  float64
#  3   last_scraped                                  19655 non-null  object
#  4   source                                        19655 non-null  object
#  5   name                                          19655 non-null  object
#  6   description                                   19632 non-null  object
#  7   neighborhood_overview                         8342 non-null   object
#  8   picture_url                                   19655 non-null  object
# ...

# %%
esp.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               5227
# Length: 75, dtype: int64

# %%
numericas2=esp.select_dtypes(include=['float']).columns
esp[numericas2]=esp[numericas2].fillna(esp[numericas2].mean())
categoricas2=esp.select_dtypes(include=['object']).columns
esp[categoricas2]=esp[categoricas2].fillna(value='Sin registro')

# %%
esp.isnull().sum()
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %% [markdown]
# ### México

# %%
mex = pd.read_csv('DF_Mexico.csv')

# %%
mex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24224 entries, 0 to 24223
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            24224 non-null  int64
#  1   listing_url                                   24224 non-null  object
#  2   scrape_id                                     24224 non-null  int64
#  3   last_scraped                                  24224 non-null  object
#  4   source                                        24224 non-null  object
#  5   name                                          24223 non-null  object
#  6   description                                   23296 non-null  object
#  7   neighborhood_overview                         15145 non-null  object
#  8   picture_url                                   24224 non-null  object
# ...

# %%
mex.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3596
# Length: 75, dtype: int64

# %%
numericas3=mex.select_dtypes(include=['float']).columns
mex[numericas3]=mex[numericas3].fillna(mex[numericas3].mean())
categoricas3=mex.select_dtypes(include=['object']).columns
mex[categoricas3]=mex[categoricas3].fillna(value='Sin registro')

# %%
mex.isnull().sum()
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %% [markdown]
# ## **Eliminar outliers**

# %% [markdown]
# ### California

# %% [markdown]
# Modificar columna 'host_acceptance_rate'

# %%
calif['host_acceptance_rate'] = calif['host_acceptance_rate'].replace('Sin registro', 0)

# %%
calif['host_acceptance_rate'] = calif['host_acceptance_rate'].str.replace('%', '')

# %%
calif['host_acceptance_rate'].unique()
# Out:
# array(['100', '71', '73', '0', '90', '95', '67', '61', '84', nan, '82',
#        '91', '80', '93', '94', '96', '60', '83', '87', '99', '89', '62',
#        '22', '75', '98', '85', '97', '92', '55', '69', '88', '86', '77',
#        '38', '32', '76', '66', '81', '50', '72', '17', '79', '58', '46',
#        '63', '43', '25', '54', '13', '40', '74', '29', '49', '47', '33',
#        '30', '12', '14', '34', '78', '15', '20', '56', '18', '59', '39',
#        '70', '57', '11', '45', '27', '64', '53', '41', '23', '7', '44',
#        '48', '52', '65', '36', '21', '42', '26', '68', '31', '16'],
#       dtype=object)

# %%
calif['host_acceptance_rate'] = calif['host_acceptance_rate'].fillna(0)

# %%
calif['host_acceptance_rate'] = calif['host_acceptance_rate'].astype(int)

# %%
calif['host_acceptance_rate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6936 entries, 0 to 6935
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 6936 non-null   int64
# dtypes: int64(1)
# memory usage: 54.3 KB

# %% [markdown]
# Modificar columna 'bathrooms_text'

# %%
calif['bathrooms_text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6936 entries, 0 to 6935
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 6936 non-null   object
# dtypes: object(1)
# memory usage: 54.3+ KB

# %%
calif['bathrooms_text'] = calif['bathrooms_text'].replace('Sin registro', 0)

# %%
calif['bathrooms_text'].isnull().sum()
# Out:
# 0

# %%
calif['bathrooms_text'] =calif['bathrooms_text'].str.extract(r'(\d+)').fillna(0).astype(float)

# %%
calif['bathrooms_text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6936 entries, 0 to 6935
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 6936 non-null   float64
# dtypes: float64(1)
# memory usage: 54.3 KB

# %%
calif['bathrooms_text'].unique
# Out:
# <bound method Series.unique of 0       1.0
# 1       1.0
# 2       4.0
# 3       1.0
# 4       1.0
#        ...
# 6931    1.0
# 6932    1.0
# 6933    1.0
# 6934    1.0
# 6935    1.0
# Name: bathrooms_text, Length: 6936, dtype: float64>

# %% [markdown]
# Modificar columna 'price'

# %%
calif['price'].unique
# Out:
# <bound method Series.unique of 0       $202.00
# 1       $235.00
# 2        $56.00
# 3       $575.00
# 4       $110.00
#          ...
# 6931    $164.00
# 6932    $228.00
# 6933    $104.00
# 6934     $65.00
# 6935    $375.00
# Name: price, Length: 6936, dtype: object>

# %%
calif['price'] = calif['price'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# <ipython-input-236-dcb4f0a1b1c4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   calif['price'] = calif['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
calif['price'].unique
# Out:
# <bound method Series.unique of 0       202.0
# 1       235.0
# 2        56.0
# 3       575.0
# 4       110.0
#         ...
# 6931    164.0
# 6932    228.0
# 6933    104.0
# 6934     65.0
# 6935    375.0
# Name: price, Length: 6936, dtype: float64>

# %% [markdown]
# Variables cuantitativas

# %%
df_Cal = calif.select_dtypes(include=['int', 'float'])
df_Cal
# Out:
#              ï»¿id     scrape_id    host_id  host_acceptance_rate  \
# 0     9.580000e+02  2.020000e+13       1169                   100
# 1     5.858000e+03  2.020000e+13       8904                    71
# 2     8.142000e+03  2.020000e+13      21994                    73
# 3     8.339000e+03  2.020000e+13      24215                     0
# 4     8.739000e+03  2.020000e+13       7149                    90
# ...            ...           ...        ...                   ...
# 6931  8.180000e+17  2.020000e+13  495900269                   100
# 6932  8.180000e+17  2.020000e+13  499392537                     0
# 6933  8.180000e+17  2.020000e+13  499294716                     0
# 6934  8.180000e+17  2.020000e+13  485596413                    50
# 6935  8.190000e+17  2.020000e+13    4836128                     0
#
#       host_listings_count  host_total_listings_count  \
# 0                       1                          1
# 1                       2                          2
# ...

# %%
df_Cal.columns
# Out:
# Index(['ï»¿id', 'scrape_id', 'host_id', 'host_acceptance_rate',
#        'host_listings_count', 'host_total_listings_count',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
# ...

# %%
df_Cal.isnull().sum()
# Out:
# ï»¿id                                              0
# scrape_id                                          0
# host_id                                            0
# host_acceptance_rate                               0
# host_listings_count                                0
# host_total_listings_count                          0
# neighbourhood_group_cleansed                    6936
# latitude                                           0
# longitude                                          0
# accommodates                                       0
# bathrooms                                       6936
# bathrooms_text                                     0
# bedrooms                                           0
# beds                                               0
# price                                              0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# ...

# %%
df_Cal.shape
# Out:
# (6936, 43)

# %%
df_Cal = df_Cal.drop(['neighbourhood_group_cleansed','bathrooms', 'calendar_updated'], axis=1)
df_Cal
# Out:
#              ï»¿id     scrape_id    host_id  host_acceptance_rate  \
# 0     9.580000e+02  2.020000e+13       1169                   100
# 1     5.858000e+03  2.020000e+13       8904                    71
# 2     8.142000e+03  2.020000e+13      21994                    73
# 3     8.339000e+03  2.020000e+13      24215                     0
# 4     8.739000e+03  2.020000e+13       7149                    90
# ...            ...           ...        ...                   ...
# 6931  8.180000e+17  2.020000e+13  495900269                   100
# 6932  8.180000e+17  2.020000e+13  499392537                     0
# 6933  8.180000e+17  2.020000e+13  499294716                     0
# 6934  8.180000e+17  2.020000e+13  485596413                    50
# 6935  8.190000e+17  2.020000e+13    4836128                     0
#
#       host_listings_count  host_total_listings_count   latitude   longitude  \
# 0                       1                          1  37.770280 -122.433170
# ...

# %%
df_Cal.isnull().sum()
# Out:
# ï»¿id                                           0
# scrape_id                                       0
# host_id                                         0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# ...

# %%
fig = plt.figure(figsize =(15, 8))
df_Cal.plot(kind='box', vert=False)
plt.title("Valores Atípicos de California")
plt.show() #dibujamos el diagrama

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df_Cal

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido ï»¿id                                           1.067459e+08
# scrape_id                                       2.020000e+13
# host_id                                         4.243084e+08
# host_acceptance_rate                            1.405000e+02
# host_listings_count                             3.850000e+01
# host_total_listings_count                       5.700000e+01
# latitude                                        3.783859e+01
# longitude                                      -1.223622e+02
# accommodates                                    7.000000e+00
# bathrooms_text                                  1.000000e+00
# bedrooms                                        3.500000e+00
# beds                                            3.500000e+00
# price                                           4.765000e+02
# minimum_nights                                  7.200000e+01
# maximum_nights                                  2.769000e+03
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= df_Cal[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#              ï»¿id  scrape_id      host_id  host_acceptance_rate  \
# 0              NaN        NaN          NaN                   NaN
# 1              NaN        NaN          NaN                   NaN
# 2              NaN        NaN          NaN                   NaN
# 3              NaN        NaN          NaN                   0.0
# 4              NaN        NaN          NaN                   NaN
# ...            ...        ...          ...                   ...
# 6931  8.180000e+17        NaN  495900269.0                   NaN
# 6932  8.180000e+17        NaN  499392537.0                   0.0
# 6933  8.180000e+17        NaN  499294716.0                   0.0
# 6934  8.180000e+17        NaN  485596413.0                   NaN
# 6935  8.190000e+17        NaN          NaN                   0.0
#
#       host_listings_count  host_total_listings_count  latitude  longitude  \
# 0                     NaN                        NaN       NaN        NaN
# ...

# %%
#Obtenemos datos limpios del Dataframe
Cal_iqr= df_Cal[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
Cal_iqr
# Out:
#        ï»¿id     scrape_id    host_id  host_acceptance_rate  \
# 0      958.0  2.020000e+13     1169.0                 100.0
# 1     5858.0  2.020000e+13     8904.0                  71.0
# 2     8142.0  2.020000e+13    21994.0                  73.0
# 3     8339.0  2.020000e+13    24215.0                   NaN
# 4     8739.0  2.020000e+13     7149.0                  90.0
# ...      ...           ...        ...                   ...
# 6931     NaN  2.020000e+13        NaN                 100.0
# 6932     NaN  2.020000e+13        NaN                   NaN
# 6933     NaN  2.020000e+13        NaN                   NaN
# 6934     NaN  2.020000e+13        NaN                  50.0
# 6935     NaN  2.020000e+13  4836128.0                   NaN
#
#       host_listings_count  host_total_listings_count   latitude   longitude  \
# 0                     1.0                        1.0  37.770280 -122.433170
# 1                     2.0                        2.0  37.744740 -122.420890
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Cal_iqr.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                           1573
# scrape_id                                          0
# host_id                                          413
# host_acceptance_rate                            1043
# host_listings_count                             1128
# host_total_listings_count                       1196
# latitude                                           0
# longitude                                        327
# accommodates                                     279
# bathrooms_text                                  1488
# bedrooms                                         228
# beds                                             558
# price                                            601
# minimum_nights                                   200
# maximum_nights                                     4
# minimum_minimum_nights                           231
# maximum_minimum_nights                           346
# minimum_maximum_nights                            21
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
Cal_clean=Cal_iqr.copy()
Cal_clean=Cal_clean.fillna(round(Cal_iqr.mean(),1))
Cal_clean
# Out:
#            ï»¿id     scrape_id     host_id  host_acceptance_rate  \
# 0          958.0  2.020000e+13      1169.0                 100.0
# 1         5858.0  2.020000e+13      8904.0                  71.0
# 2         8142.0  2.020000e+13     21994.0                  73.0
# 3         8339.0  2.020000e+13     24215.0                  91.2
# 4         8739.0  2.020000e+13      7149.0                  90.0
# ...          ...           ...         ...                   ...
# 6931  27790615.3  2.020000e+13  87507815.4                 100.0
# 6932  27790615.3  2.020000e+13  87507815.4                  91.2
# 6933  27790615.3  2.020000e+13  87507815.4                  91.2
# 6934  27790615.3  2.020000e+13  87507815.4                  50.0
# 6935  27790615.3  2.020000e+13   4836128.0                  91.2
#
#       host_listings_count  host_total_listings_count   latitude   longitude  \
# 0                     1.0                        1.0  37.770280 -122.433170
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Cal_clean.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                           0
# scrape_id                                       0
# host_id                                         0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# ...

# %%
#Convertir DataFrame a CSV
Cal_clean.to_csv("California_limpios.csv")
#descargar archivo filtrado en csv
from google.colab import files    
files.download("California_limpios.csv")

# %% [markdown]
# ### España

# %% [markdown]
# Modificar columna 'host_acceptance_rate'

# %%
esp['host_acceptance_rate'] = esp['host_acceptance_rate'].replace('Sin registro', 0)

# %%
esp['host_acceptance_rate'] = esp['host_acceptance_rate'].str.replace('%', '')

# %%
esp['host_acceptance_rate'].unique()
# Out:
# array(['90', '42', '80', '91', '0', '100', nan, '57', '99', '12', '65',
#        '64', '98', '67', '50', '74', '92', '71', '39', '52', '97', '95',
#        '84', '94', '83', '25', '76', '45', '77', '27', '96', '78', '20',
#        '93', '82', '59', '43', '87', '81', '85', '36', '58', '44', '55',
#        '86', '60', '62', '88', '40', '68', '33', '75', '70', '69', '89',
#        '38', '72', '21', '54', '63', '22', '9', '73', '17', '56', '31',
#        '79', '23', '32', '41', '66', '61', '49', '8', '46', '24', '53',
#        '51', '37', '18', '47', '30', '29', '13', '11', '48', '35', '14',
#        '7', '34', '10', '26'], dtype=object)

# %%
esp['host_acceptance_rate'] = esp['host_acceptance_rate'].fillna(0)

# %%
esp['host_acceptance_rate'] = esp['host_acceptance_rate'].astype(int)

# %%
esp['host_acceptance_rate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 19655 entries, 0 to 19654
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 19655 non-null  int64
# dtypes: int64(1)
# memory usage: 153.7 KB

# %% [markdown]
# Modificar columna 'bathrooms_text'

# %%
esp['bathrooms_text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 19655 entries, 0 to 19654
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 19655 non-null  object
# dtypes: object(1)
# memory usage: 153.7+ KB

# %%
esp['bathrooms_text'] = esp['bathrooms_text'].replace('Sin registro', 0)

# %%
esp['bathrooms_text'].isnull().sum()
# Out:
# 0

# %%
esp['bathrooms_text'] =esp['bathrooms_text'].str.extract(r'(\d+)').fillna(0).astype(float)

# %%
esp['bathrooms_text'].unique
# Out:
# <bound method Series.unique of 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 19650    5.0
# 19651    1.0
# 19652    1.0
# 19653    1.0
# 19654    1.0
# Name: bathrooms_text, Length: 19655, dtype: float64>

# %% [markdown]
# Modificar columna 'price'

# %%
esp['price'].unique
# Out:
# <bound method Series.unique of 0         $42.00
# 1         $47.00
# 2         $74.00
# 3         $45.00
# 4        $120.00
#           ...
# 19650    $209.00
# 19651     $52.00
# 19652     $66.00
# 19653    $108.00
# 19654     $73.00
# Name: price, Length: 19655, dtype: object>

# %%
esp['price'] = esp['price'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# <ipython-input-264-dab1ea9aa3a1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   esp['price'] = esp['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
esp['price'].unique
# Out:
# <bound method Series.unique of 0         42.0
# 1         47.0
# 2         74.0
# 3         45.0
# 4        120.0
#          ...
# 19650    209.0
# 19651     52.0
# 19652     66.0
# 19653    108.0
# 19654     73.0
# Name: price, Length: 19655, dtype: float64>

# %% [markdown]
# Variables cuantitativas

# %%
df_esp = esp.select_dtypes(include=['int', 'float'])
df_esp
# Out:
#                  id     scrape_id    host_id  host_acceptance_rate  \
# 0      1.455100e+04  2.023030e+13      57237                    90
# 1      1.205757e+06  2.023030e+13    6586355                    42
# 2      1.212820e+06  2.023030e+13    6620645                    80
# 3      7.516380e+05  2.023030e+13    3680160                    91
# 4      4.134200e+04  2.023030e+13     180072                     0
# ...             ...           ...        ...                   ...
# 19650  8.583870e+17  2.023030e+13   26281633                   100
# 19651  8.583960e+17  2.023030e+13  444428600                   100
# 19652  8.584110e+17  2.023030e+13  491503593                    50
# 19653  8.584180e+17  2.023030e+13  389605038                    99
# 19654  8.584240e+17  2.023030e+13  491503593                    50
#
#        host_listings_count  host_total_listings_count  \
# 0                      1.0                        5.0
# ...

# %%
df_esp.isnull().sum()
# Out:
# id                                                  0
# scrape_id                                           0
# host_id                                             0
# host_acceptance_rate                                0
# host_listings_count                                 0
# host_total_listings_count                           0
# neighbourhood_group_cleansed                    19655
# latitude                                            0
# longitude                                           0
# accommodates                                        0
# bathrooms                                       19655
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# ...

# %%
df_esp = df_esp.drop(['neighbourhood_group_cleansed','bathrooms', 'calendar_updated'], axis=1)
df_esp
# Out:
#                  id     scrape_id    host_id  host_acceptance_rate  \
# 0      1.455100e+04  2.023030e+13      57237                    90
# 1      1.205757e+06  2.023030e+13    6586355                    42
# 2      1.212820e+06  2.023030e+13    6620645                    80
# 3      7.516380e+05  2.023030e+13    3680160                    91
# 4      4.134200e+04  2.023030e+13     180072                     0
# ...             ...           ...        ...                   ...
# 19650  8.583870e+17  2.023030e+13   26281633                   100
# 19651  8.583960e+17  2.023030e+13  444428600                   100
# 19652  8.584110e+17  2.023030e+13  491503593                    50
# 19653  8.584180e+17  2.023030e+13  389605038                    99
# 19654  8.584240e+17  2.023030e+13  491503593                    50
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                      1.0                        5.0  41.996500   2.836460
# ...

# %%
df_esp.isnull().sum()
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# ...

# %%
fig = plt.figure(figsize =(15, 8))
df_esp.plot(kind='box', vert=False)
plt.title("Valores Atípicos de España")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df_esp

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido id                                              1.430535e+18
# scrape_id                                       2.023030e+13
# host_id                                         5.298792e+08
# host_acceptance_rate                            1.210000e+02
# host_listings_count                             1.560000e+02
# host_total_listings_count                       2.270000e+02
# latitude                                        4.288548e+01
# longitude                                       3.623007e+00
# accommodates                                    9.000000e+00
# bathrooms_text                                  3.500000e+00
# bedrooms                                        4.500000e+00
# beds                                            9.500000e+00
# price                                           3.875000e+02
# minimum_nights                                  1.100000e+01
# maximum_nights                                  2.722500e+03
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= df_esp[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#        id  scrape_id  host_id  host_acceptance_rate  host_listings_count  \
# 0     NaN        NaN      NaN                   NaN                  NaN
# 1     NaN        NaN      NaN                  42.0                  NaN
# 2     NaN        NaN      NaN                   NaN                  NaN
# 3     NaN        NaN      NaN                   NaN                  NaN
# 4     NaN        NaN      NaN                   0.0                  NaN
# ...    ..        ...      ...                   ...                  ...
# 19650 NaN        NaN      NaN                   NaN                  NaN
# 19651 NaN        NaN      NaN                   NaN                  NaN
# 19652 NaN        NaN      NaN                  50.0                  NaN
# 19653 NaN        NaN      NaN                   NaN                  NaN
# 19654 NaN        NaN      NaN                  50.0                  NaN
#
#        host_total_listings_count  latitude  longitude  accommodates  \
# ...

# %%
#Obtenemos datos limpios del Dataframe
esp_iqr= df_esp[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
esp_iqr
# Out:
#                  id     scrape_id    host_id  host_acceptance_rate  \
# 0      1.455100e+04  2.023030e+13      57237                  90.0
# 1      1.205757e+06  2.023030e+13    6586355                   NaN
# 2      1.212820e+06  2.023030e+13    6620645                  80.0
# 3      7.516380e+05  2.023030e+13    3680160                  91.0
# 4      4.134200e+04  2.023030e+13     180072                   NaN
# ...             ...           ...        ...                   ...
# 19650  8.583870e+17  2.023030e+13   26281633                 100.0
# 19651  8.583960e+17  2.023030e+13  444428600                 100.0
# 19652  8.584110e+17  2.023030e+13  491503593                   NaN
# 19653  8.584180e+17  2.023030e+13  389605038                  99.0
# 19654  8.584240e+17  2.023030e+13  491503593                   NaN
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                      1.0                        5.0  41.996500   2.836460
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=esp_iqr.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# scrape_id                                          0
# host_id                                            0
# host_acceptance_rate                            2961
# host_listings_count                             1682
# host_total_listings_count                       2447
# latitude                                           0
# longitude                                        926
# accommodates                                    1616
# bathrooms_text                                  1048
# bedrooms                                        1355
# beds                                             565
# price                                           1944
# minimum_nights                                   449
# maximum_nights                                     0
# minimum_minimum_nights                           434
# maximum_minimum_nights                          1009
# minimum_maximum_nights                             0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
esp_clean=esp_iqr.copy()
esp_clean=esp_clean.fillna(round(esp_iqr.mean(),1))
esp_clean
# Out:
#                  id     scrape_id    host_id  host_acceptance_rate  \
# 0      1.455100e+04  2.023030e+13      57237                  90.0
# 1      1.205757e+06  2.023030e+13    6586355                  95.3
# 2      1.212820e+06  2.023030e+13    6620645                  80.0
# 3      7.516380e+05  2.023030e+13    3680160                  91.0
# 4      4.134200e+04  2.023030e+13     180072                  95.3
# ...             ...           ...        ...                   ...
# 19650  8.583870e+17  2.023030e+13   26281633                 100.0
# 19651  8.583960e+17  2.023030e+13  444428600                 100.0
# 19652  8.584110e+17  2.023030e+13  491503593                  95.3
# 19653  8.584180e+17  2.023030e+13  389605038                  99.0
# 19654  8.584240e+17  2.023030e+13  491503593                  95.3
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                      1.0                        5.0  41.996500   2.836460
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=esp_clean.isnull().sum()
valores_nulos
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# ...

# %%
#Convertir DataFrame a CSV
esp_clean.to_csv("España_limpios.csv")
#descargar archivo filtrado en csv
from google.colab import files    
files.download("España_limpios.csv")

# %% [markdown]
# ### México

# %% [markdown]
# # **Etapa 2**

# %% [markdown]
# Modificar columna 'host_acceptance_rate'

# %%
mex['host_acceptance_rate'] = mex['host_acceptance_rate'].replace('Sin registro', 0)

# %%
mex['host_acceptance_rate'] = mex['host_acceptance_rate'].str.replace('%', '')

# %%
mex['host_acceptance_rate'].unique()
# Out:
# array([nan, '90', '86', '70', '95', '100', '58', '98', '73', '87', '0',
#        '99', '40', '33', '77', '75', '97', '94', '81', '89', '60', '91',
#        '92', '85', '93', '71', '88', '46', '82', '50', '64', '74', '63',
#        '67', '96', '20', '44', '47', '13', '43', '83', '80', '35', '38',
#        '9', '59', '68', '25', '76', '65', '3', '66', '69', '10', '19',
#        '54', '78', '84', '56', '39', '15', '49', '53', '79', '17', '42',
#        '52', '57', '27', '28', '41', '23', '36', '21', '31', '48', '11',
#        '14', '72', '7', '22', '61', '8', '62', '55', '32', '29', '18',
#        '24', '30', '34'], dtype=object)

# %%
mex['host_acceptance_rate'] = mex['host_acceptance_rate'].fillna(0)

# %%
mex['host_acceptance_rate'] = mex['host_acceptance_rate'].astype(int)

# %%
mex['host_acceptance_rate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 24224 entries, 0 to 24223
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 24224 non-null  int64
# dtypes: int64(1)
# memory usage: 189.4 KB

# %% [markdown]
# Modificar columna 'bathrooms_text'

# %%
mex['bathrooms_text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 24224 entries, 0 to 24223
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 24224 non-null  object
# dtypes: object(1)
# memory usage: 189.4+ KB

# %%
mex['bathrooms_text'] = mex['bathrooms_text'].replace('Sin registro', 0)

# %%
mex['bathrooms_text'].isnull().sum()
# Out:
# 0

# %%
mex['bathrooms_text'] =mex['bathrooms_text'].str.extract(r'(\d+)').fillna(0).astype(float)

# %%
mex['bathrooms_text'].unique
# Out:
# <bound method Series.unique of 0        1.0
# 1        1.0
# 2        2.0
# 3        1.0
# 4        5.0
#         ...
# 24219    1.0
# 24220    1.0
# 24221    2.0
# 24222    1.0
# 24223    1.0
# Name: bathrooms_text, Length: 24224, dtype: float64>

# %% [markdown]
# Modificar columna 'price'

# %%
mex['price'].unique
# Out:
# <bound method Series.unique of 0         $1,434.00
# 1           $830.00
# 2         $1,469.00
# 3         $3,658.00
# 4        $18,000.00
#             ...
# 24219       $760.00
# 24220     $1,520.00
# 24221       $533.00
# 24222     $1,200.00
# 24223     $1,720.00
# Name: price, Length: 24224, dtype: object>

# %%
mex['price'] = mex['price'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# <ipython-input-290-8ff51e4f3c97>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   mex['price'] = mex['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
esp['price'].unique
# Out:
# <bound method Series.unique of 0         42.0
# 1         47.0
# 2         74.0
# 3         45.0
# 4        120.0
#          ...
# 19650    209.0
# 19651     52.0
# 19652     66.0
# 19653    108.0
# 19654     73.0
# Name: price, Length: 19655, dtype: float64>

# %% [markdown]
# Variables cuantitativas

# %%
df_mex = mex.select_dtypes(include=['int', 'float'])
df_mex
# Out:
#                        id       scrape_id    host_id  host_acceptance_rate  \
# 0                 2056638  20230329041210   10531228                     0
# 1                 2072354  20230329041210   16840050                     0
# 2                  696037  20230329041210    3531879                    90
# 3                   35797  20230329041210     153786                     0
# 4                   44616  20230329041210     196253                    86
# ...                   ...             ...        ...                   ...
# 24219  853923589855678923  20230329041210  488030249                   100
# 24220  853966732274073000  20230329041210  506816029                     0
# 24221  854225071295768399  20230329041210  154670560                    96
# 24222  854247693069190865  20230329041210    7799414                   100
# 24223  854260329845513725  20230329041210  506864314                   100
#
#        host_listings_count  host_total_listings_count  \
# ...

# %%
df_mex.isnull().sum()
# Out:
# id                                                  0
# scrape_id                                           0
# host_id                                             0
# host_acceptance_rate                                0
# host_listings_count                                 0
# host_total_listings_count                           0
# neighbourhood_group_cleansed                    24224
# latitude                                            0
# longitude                                           0
# accommodates                                        0
# bathrooms                                       24224
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# ...

# %%
df_mex = df_mex.drop(['neighbourhood_group_cleansed','bathrooms', 'calendar_updated','license'], axis=1)
df_mex
# Out:
#                        id       scrape_id    host_id  host_acceptance_rate  \
# 0                 2056638  20230329041210   10531228                     0
# 1                 2072354  20230329041210   16840050                     0
# 2                  696037  20230329041210    3531879                    90
# 3                   35797  20230329041210     153786                     0
# 4                   44616  20230329041210     196253                    86
# ...                   ...             ...        ...                   ...
# 24219  853923589855678923  20230329041210  488030249                   100
# 24220  853966732274073000  20230329041210  506816029                     0
# 24221  854225071295768399  20230329041210  154670560                    96
# 24222  854247693069190865  20230329041210    7799414                   100
# 24223  854260329845513725  20230329041210  506864314                   100
#
# ...

# %%
df_mex.isnull().sum()
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# ...

# %%
fig = plt.figure(figsize =(15, 8))
df_mex.plot(kind='box', vert=False)
plt.title("Valores Atípicos de México")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df_mex

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido id                                              1.690170e+18
# scrape_id                                       2.023033e+13
# host_id                                         6.839189e+08
# host_acceptance_rate                            1.150000e+02
# host_listings_count                             2.850000e+01
# host_total_listings_count                       3.200000e+01
# latitude                                        1.949915e+01
# longitude                                      -9.911735e+01
# accommodates                                    7.000000e+00
# bathrooms_text                                  3.500000e+00
# bedrooms                                        3.500000e+00
# beds                                            3.500000e+00
# price                                           3.161500e+03
# minimum_nights                                  3.500000e+00
# maximum_nights                                  2.542500e+03
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= df_mex[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#        id  scrape_id  host_id  host_acceptance_rate  host_listings_count  \
# 0     NaN        NaN      NaN                   0.0                  NaN
# 1     NaN        NaN      NaN                   0.0                  NaN
# 2     NaN        NaN      NaN                   NaN                  NaN
# 3     NaN        NaN      NaN                   0.0                  NaN
# 4     NaN        NaN      NaN                   NaN                  NaN
# ...    ..        ...      ...                   ...                  ...
# 24219 NaN        NaN      NaN                   NaN                  NaN
# 24220 NaN        NaN      NaN                   0.0                  NaN
# 24221 NaN        NaN      NaN                   NaN                  NaN
# 24222 NaN        NaN      NaN                   NaN                  NaN
# 24223 NaN        NaN      NaN                   NaN                  NaN
#
#        host_total_listings_count  latitude  longitude  accommodates  \
# ...

# %%
#Obtenemos datos limpios del Dataframe
mex_iqr= df_mex[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
mex_iqr
# Out:
#                        id       scrape_id    host_id  host_acceptance_rate  \
# 0                 2056638  20230329041210   10531228                   NaN
# 1                 2072354  20230329041210   16840050                   NaN
# 2                  696037  20230329041210    3531879                  90.0
# 3                   35797  20230329041210     153786                   NaN
# 4                   44616  20230329041210     196253                  86.0
# ...                   ...             ...        ...                   ...
# 24219  853923589855678923  20230329041210  488030249                 100.0
# 24220  853966732274073000  20230329041210  506816029                   NaN
# 24221  854225071295768399  20230329041210  154670560                  96.0
# 24222  854247693069190865  20230329041210    7799414                 100.0
# 24223  854260329845513725  20230329041210  506864314                 100.0
#
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=mex_iqr.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# scrape_id                                          0
# host_id                                            0
# host_acceptance_rate                            4267
# host_listings_count                             3324
# host_total_listings_count                       3453
# latitude                                        1490
# longitude                                       2594
# accommodates                                    1090
# bathrooms_text                                   523
# bedrooms                                         640
# beds                                            2347
# price                                           1707
# minimum_nights                                  3195
# maximum_nights                                     1
# minimum_minimum_nights                          3082
# maximum_minimum_nights                          1895
# minimum_maximum_nights                             5
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
mex_clean=mex_iqr.copy()
mex_clean=mex_clean.fillna(round(mex_iqr.mean(),1))
mex_clean
# Out:
#                        id       scrape_id    host_id  host_acceptance_rate  \
# 0                 2056638  20230329041210   10531228                  97.5
# 1                 2072354  20230329041210   16840050                  97.5
# 2                  696037  20230329041210    3531879                  90.0
# 3                   35797  20230329041210     153786                  97.5
# 4                   44616  20230329041210     196253                  86.0
# ...                   ...             ...        ...                   ...
# 24219  853923589855678923  20230329041210  488030249                 100.0
# 24220  853966732274073000  20230329041210  506816029                  97.5
# 24221  854225071295768399  20230329041210  154670560                  96.0
# 24222  854247693069190865  20230329041210    7799414                 100.0
# 24223  854260329845513725  20230329041210  506864314                 100.0
#
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=mex_clean.isnull().sum()
valores_nulos
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# ...

# %%
#Convertir DataFrame a CSV
mex_clean.to_csv("Mexico_limpios.csv")
#descargar archivo filtrado en csv
from google.colab import files    
files.download("Mexico_limpios.csv")

# %% [markdown]
# texto en cursiva# Etapa 2

# %%
Cal_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6936 entries, 0 to 6935
# Data columns (total 40 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ï»¿id                                         6936 non-null   float64
#  1   scrape_id                                     6936 non-null   float64
#  2   host_id                                       6936 non-null   float64
#  3   host_acceptance_rate                          6936 non-null   float64
#  4   host_listings_count                           6936 non-null   float64
#  5   host_total_listings_count                     6936 non-null   float64
#  6   latitude                                      6936 non-null   float64
#  7   longitude                                     6936 non-null   float64
#  8   accommodates                                  6936 non-null   float64
# ...

# %% [markdown]
# ## a) host_acceptance_rate > 50%

# %% [markdown]
# ### California

# %%
filtroA=Cal_clean[Cal_clean["host_acceptance_rate"] > 50]
filtroA
# Out:
#            ï»¿id     scrape_id      host_id  host_acceptance_rate  \
# 0          958.0  2.020000e+13       1169.0                 100.0
# 1         5858.0  2.020000e+13       8904.0                  71.0
# 2         8142.0  2.020000e+13      21994.0                  73.0
# 3         8339.0  2.020000e+13      24215.0                  91.2
# 4         8739.0  2.020000e+13       7149.0                  90.0
# ...          ...           ...          ...                   ...
# 6930  27790615.3  2.020000e+13  286802480.0                 100.0
# 6931  27790615.3  2.020000e+13   87507815.4                 100.0
# 6932  27790615.3  2.020000e+13   87507815.4                  91.2
# 6933  27790615.3  2.020000e+13   87507815.4                  91.2
# 6935  27790615.3  2.020000e+13    4836128.0                  91.2
#
#       host_listings_count  host_total_listings_count   latitude   longitude  \
# 0                     1.0                        1.0  37.770280 -122.433170
# ...

# %% [markdown]
# ### España

# %%
filtroA_e=esp_clean[esp_clean["host_acceptance_rate"] > 50]
filtroA_e
# Out:
#                  id     scrape_id    host_id  host_acceptance_rate  \
# 0      1.455100e+04  2.023030e+13      57237                  90.0
# 1      1.205757e+06  2.023030e+13    6586355                  95.3
# 2      1.212820e+06  2.023030e+13    6620645                  80.0
# 3      7.516380e+05  2.023030e+13    3680160                  91.0
# 4      4.134200e+04  2.023030e+13     180072                  95.3
# ...             ...           ...        ...                   ...
# 19650  8.583870e+17  2.023030e+13   26281633                 100.0
# 19651  8.583960e+17  2.023030e+13  444428600                 100.0
# 19652  8.584110e+17  2.023030e+13  491503593                  95.3
# 19653  8.584180e+17  2.023030e+13  389605038                  99.0
# 19654  8.584240e+17  2.023030e+13  491503593                  95.3
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                      1.0                        5.0  41.996500   2.836460
# ...

# %% [markdown]
# ### México

# %%
filtroA_m=mex_clean[mex_clean["host_acceptance_rate"] > 50]
filtroA_m
# Out:
#                        id       scrape_id    host_id  host_acceptance_rate  \
# 0                 2056638  20230329041210   10531228                  97.5
# 1                 2072354  20230329041210   16840050                  97.5
# 2                  696037  20230329041210    3531879                  90.0
# 3                   35797  20230329041210     153786                  97.5
# 4                   44616  20230329041210     196253                  86.0
# ...                   ...             ...        ...                   ...
# 24219  853923589855678923  20230329041210  488030249                 100.0
# 24220  853966732274073000  20230329041210  506816029                  97.5
# 24221  854225071295768399  20230329041210  154670560                  96.0
# 24222  854247693069190865  20230329041210    7799414                 100.0
# 24223  854260329845513725  20230329041210  506864314                 100.0
#
# ...

# %% [markdown]
# ## b) Solo los registros con categoría superhost

# %% [markdown]
# ### California

# %%
filtroB = calif[calif['host_is_superhost'] == 't']
filtroB
# Out:
#              ï»¿id                                      listing_url  \
# 0     9.580000e+02                 https://www.airbnb.com/rooms/958
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# 7     1.053700e+04               https://www.airbnb.com/rooms/10537
# 8     4.918670e+05              https://www.airbnb.com/rooms/491867
# 9     1.442420e+05              https://www.airbnb.com/rooms/144242
# ...            ...                                              ...
# 6913  8.160000e+17  https://www.airbnb.com/rooms/815561340398335999
# 6918  8.160000e+17  https://www.airbnb.com/rooms/816211107298614925
# 6919  8.170000e+17  https://www.airbnb.com/rooms/816849292948023117
# 6923  8.170000e+17  https://www.airbnb.com/rooms/816998498709351546
# 6929  8.180000e+17  https://www.airbnb.com/rooms/817686120681200035
#
#          scrape_id last_scraped           source  \
# 0     2.020000e+13   06/03/2023      city scrape
# ...

# %% [markdown]
# ### España

# %%
filtroB_e = esp[esp['host_is_superhost'] == 't']
filtroB_e
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 8      4.540000e+04               https://www.airbnb.com/rooms/45400
# 10     7.536040e+05              https://www.airbnb.com/rooms/753604
# 21     1.067040e+05              https://www.airbnb.com/rooms/106704
# 23     7.667630e+05              https://www.airbnb.com/rooms/766763
# ...             ...                                              ...
# 19597  8.570060e+17  https://www.airbnb.com/rooms/857005842548581951
# 19601  8.561710e+17  https://www.airbnb.com/rooms/856170558033465178
# 19617  8.571400e+17  https://www.airbnb.com/rooms/857140341578381773
# 19628  8.576970e+17  https://www.airbnb.com/rooms/857696993901267131
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
#
#           scrape_id last_scraped       source  \
# 0      2.023030e+13   31/03/2023  city scrape
# ...

# %% [markdown]
# ### México

# %%
filtroB_m = mex[mex['host_is_superhost'] == 't']
filtroB_m
# Out:
#                        id                                      listing_url  \
# 2                  696037              https://www.airbnb.com/rooms/696037
# 6                   56074               https://www.airbnb.com/rooms/56074
# 7                   61792               https://www.airbnb.com/rooms/61792
# 8                  704779              https://www.airbnb.com/rooms/704779
# 9                  728372              https://www.airbnb.com/rooms/728372
# ...                   ...                                              ...
# 24171  855774527635077059  https://www.airbnb.com/rooms/855774527635077059
# 24179  856002521325547866  https://www.airbnb.com/rooms/856002521325547866
# 24191  856173561837114843  https://www.airbnb.com/rooms/856173561837114843
# 24203  856499834474724290  https://www.airbnb.com/rooms/856499834474724290
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
#
#             scrape_id last_scraped       source  \
# ...

# %% [markdown]
# ## c) Los registros que no hayan identificado identidad

# %% [markdown]
# ### California

# %%
filtroC = calif[calif['host_identity_verified'] == 'f']
filtroC
# Out:
#              ï»¿id                                      listing_url  \
# 6     4.909310e+05              https://www.airbnb.com/rooms/490931
# 28    1.823100e+04               https://www.airbnb.com/rooms/18231
# 38    1.932920e+05              https://www.airbnb.com/rooms/193292
# 39    2.013130e+05              https://www.airbnb.com/rooms/201313
# 71    2.311290e+05              https://www.airbnb.com/rooms/231129
# ...            ...                                              ...
# 6885  8.090000e+17  https://www.airbnb.com/rooms/808995594566778409
# 6905  8.130000e+17  https://www.airbnb.com/rooms/813099498776240866
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
# 6932  8.180000e+17  https://www.airbnb.com/rooms/818231243893035313
# 6933  8.180000e+17  https://www.airbnb.com/rooms/818396267693629070
#
#          scrape_id last_scraped       source  \
# 6     2.020000e+13   06/03/2023  city scrape
# 28    2.020000e+13   06/03/2023  city scrape
# ...

# %% [markdown]
# ### España

# %%
filtroC_e = esp[esp['host_identity_verified'] == 'f']
filtroC_e
# Out:
#                  id                                      listing_url  \
# 2      1.212820e+06             https://www.airbnb.com/rooms/1212820
# 7      1.215790e+06             https://www.airbnb.com/rooms/1215790
# 9      1.222762e+06             https://www.airbnb.com/rooms/1222762
# 30     7.848920e+05              https://www.airbnb.com/rooms/784892
# 33     1.242933e+06             https://www.airbnb.com/rooms/1242933
# ...             ...                                              ...
# 19553  8.564530e+17  https://www.airbnb.com/rooms/856453392873929103
# 19560  8.555490e+17  https://www.airbnb.com/rooms/855549250338882404
# 19561  8.564900e+17  https://www.airbnb.com/rooms/856489549604868072
# 19611  8.571160e+17  https://www.airbnb.com/rooms/857116415296321804
# 19612  8.571180e+17  https://www.airbnb.com/rooms/857117734620997270
#
#           scrape_id last_scraped       source  \
# 2      2.023030e+13   01/04/2023  city scrape
# ...

# %% [markdown]
# ### México

# %%
filtroC_m = mex[mex['host_identity_verified'] == 'f']
filtroC_m
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 21                 131610              https://www.airbnb.com/rooms/131610
# 61                 276504              https://www.airbnb.com/rooms/276504
# 68                 291804              https://www.airbnb.com/rooms/291804
# 70                 298873              https://www.airbnb.com/rooms/298873
# ...                   ...                                              ...
# 23695  841965092018895031  https://www.airbnb.com/rooms/841965092018895031
# 23873  848588787570156425  https://www.airbnb.com/rooms/848588787570156425
# 23965  849310790991650241  https://www.airbnb.com/rooms/849310790991650241
# 23966  849315893191760444  https://www.airbnb.com/rooms/849315893191760444
# 23972  849318651327303243  https://www.airbnb.com/rooms/849318651327303243
#
#             scrape_id last_scraped           source  \
# ...

# %% [markdown]
# ## d) Registros cuyo property type es 'Private room' y 'Hotel room'

# %% [markdown]
# ### California

# %%
filtroD = calif['property_type'].str.contains('Private|Hotel', case=False)
property_c = calif[filtroD]
property_c
# Out:
#              ï»¿id                                      listing_url  \
# 2     8.142000e+03                https://www.airbnb.com/rooms/8142
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# 6     4.909310e+05              https://www.airbnb.com/rooms/490931
# 7     1.053700e+04               https://www.airbnb.com/rooms/10537
# 11    1.449780e+05              https://www.airbnb.com/rooms/144978
# ...            ...                                              ...
# 6927  8.170000e+17  https://www.airbnb.com/rooms/817390268252267687
# 6929  8.180000e+17  https://www.airbnb.com/rooms/817686120681200035
# 6930  8.180000e+17  https://www.airbnb.com/rooms/818185441952600448
# 6933  8.180000e+17  https://www.airbnb.com/rooms/818396267693629070
# 6934  8.180000e+17  https://www.airbnb.com/rooms/818474518435984613
#
#          scrape_id last_scraped       source  \
# 2     2.020000e+13   06/03/2023  city scrape
# 4     2.020000e+13   06/03/2023  city scrape
# ...

# %% [markdown]
# ### España

# %%
filtroD_e = esp['property_type'].str.contains('Private|Hotel', case=False)
property_e = esp[filtroD_e]
property_e
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 1      1.205757e+06             https://www.airbnb.com/rooms/1205757
# 3      7.516380e+05              https://www.airbnb.com/rooms/751638
# 12     7.559270e+05              https://www.airbnb.com/rooms/755927
# 13     7.561450e+05              https://www.airbnb.com/rooms/756145
# ...             ...                                              ...
# 19534  8.563700e+17  https://www.airbnb.com/rooms/856369517825070847
# 19535  8.563740e+17  https://www.airbnb.com/rooms/856374162403620030
# 19546  8.528310e+17  https://www.airbnb.com/rooms/852831142413408392
# 19573  8.584720e+17  https://www.airbnb.com/rooms/858471895814418075
# 19582  8.569460e+17  https://www.airbnb.com/rooms/856946494442677878
#
#           scrape_id last_scraped       source  \
# 0      2.023030e+13   31/03/2023  city scrape
# ...

# %% [markdown]
# ### México

# %%
filtroD_m = mex['property_type'].str.contains('Private|Hotel', case=False)
property_m = mex[filtroD_m]
property_m
# Out:
#                        id                                      listing_url  \
# 7                   61792               https://www.airbnb.com/rooms/61792
# 16                 760912              https://www.airbnb.com/rooms/760912
# 17                2088218             https://www.airbnb.com/rooms/2088218
# 18                2093036             https://www.airbnb.com/rooms/2093036
# 21                 131610              https://www.airbnb.com/rooms/131610
# ...                   ...                                              ...
# 24200  856473895554110501  https://www.airbnb.com/rooms/856473895554110501
# 24213  853707681690048732  https://www.airbnb.com/rooms/853707681690048732
# 24215  853746847434924262  https://www.airbnb.com/rooms/853746847434924262
# 24218  853922041242738127  https://www.airbnb.com/rooms/853922041242738127
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
#
#             scrape_id last_scraped       source  \
# ...

# %% [markdown]
# ## **e) Registros que cuenten con bathroom > 1**

# %% [markdown]
# ### California

# %%
filtroE = df_Cal['bathrooms_text'] > 1
baths_c = df_Cal[filtroE]
baths_c
# Out:
#              ï»¿id     scrape_id    host_id  host_acceptance_rate  \
# 2     8.142000e+03  2.020000e+13      21994                    73
# 8     4.918670e+05  2.020000e+13     969518                    61
# 9     1.442420e+05  2.020000e+13     699215                    84
# 13    1.204100e+04  2.020000e+13      21994                    73
# 17    1.204200e+04  2.020000e+13      21994                    73
# ...            ...           ...        ...                   ...
# 6902  8.120000e+17  2.020000e+13    8145777                    49
# 6904  8.120000e+17  2.020000e+13    2559623                    50
# 6909  8.140000e+17  2.020000e+13  366102003                   100
# 6910  8.140000e+17  2.020000e+13   14649347                     0
# 6919  8.170000e+17  2.020000e+13     330231                    94
#
#       host_listings_count  host_total_listings_count   latitude   longitude  \
# 2                      13                         14  37.765550 -122.452130
# ...

# %% [markdown]
# ### España

# %%
filtroE_e = df_esp['bathrooms_text'] > 1
baths_e = df_esp[filtroE_e]
baths_e
# Out:
#                  id     scrape_id    host_id  host_acceptance_rate  \
# 7      1.215790e+06  2.023030e+13    3149645                     0
# 9      1.222762e+06  2.023030e+13    6404885                    57
# 11     4.876400e+04  2.023030e+13     220145                    80
# 14     1.228453e+06  2.023030e+13    6623729                    91
# 15     9.334300e+04  2.023030e+13     477826                    12
# ...             ...           ...        ...                   ...
# 19641  8.579310e+17  2.023030e+13  173153149                   100
# 19642  8.579410e+17  2.023030e+13  507641932                     0
# 19643  8.579870e+17  2.023030e+13  419014196                    33
# 19647  8.583550e+17  2.023030e+13  497533696                    98
# 19650  8.583870e+17  2.023030e+13   26281633                   100
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 7                      1.0                        1.0  41.849840   3.126500
# ...

# %% [markdown]
# ### Mexico

# %%
filtroE_m = df_mex['bathrooms_text'] > 1
baths_m = df_mex[filtroE_m]
baths_m
# Out:
#                        id       scrape_id    host_id  host_acceptance_rate  \
# 2                  696037  20230329041210    3531879                    90
# 4                   44616  20230329041210     196253                    86
# 5                 2075738  20230329041210    2339771                    70
# 9                  728372  20230329041210    3777702                    58
# 26                2118573  20230329041210   10802698                    95
# ...                   ...             ...        ...                   ...
# 24194  856456602117523747  20230329041210  499836247                   100
# 24196  856461104525515702  20230329041210  396911095                     0
# 24206  856513330497669167  20230329041210  445250346                   100
# 24210  853691389932218970  20230329041210  155903047                     0
# 24221  854225071295768399  20230329041210  154670560                    96
#
# ...

# %% [markdown]
# ## **f) Registros cuyo precio sea mayor a 10,000 y que sean de tipo "Entire home"**

# %% [markdown]
# ### California

# %%
filtroF = (calif['price'] > 10000) & (calif['property_type'] == 'Entire home')
df1 = calif[filtroF]
df1
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### España

# %%
esp['price'] = pd.to_numeric(esp['price'], errors='coerce')
esp['property_type'] = esp['property_type'].astype(str)

# %%
filtroF_e = (esp['price'] > 10000) & (esp['property_type'] == 'Entire home')
df2 = calif[filtroF_e]
df2
# Out:
# <ipython-input-322-a38136e9b0d9>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = calif[filtroF_e]
#          ï»¿id                           listing_url     scrape_id  \
# 753  4157431.0  https://www.airbnb.com/rooms/4157431  2.020000e+13
#
#     last_scraped       source                                         name  \
# 753   06/03/2023  city scrape  Spacious 1 BR / 1 BA Living in Russian Hill
#
#                                            description  \
# 753  A beautiful, spacious apartment in one of the ...
#
#                                  neighborhood_overview  \
# 753  Russian Hill is a neighborhood with that rare ...
#
#                                            picture_url   host_id  ...  \
# 753  https://a0.muscache.com/pictures/53186930/6a03...  21573904  ...
#
#     review_scores_communication review_scores_location review_scores_value  \
# 753                         5.0                   4.96                4.69
#
# ...

# %% [markdown]
# ### México

# %%
filtroF_m = (mex['price'] > 10000) & (mex['property_type'] == 'Entire home')
df3 = mex[filtroF_m]
df3
# Out:
#                        id                                      listing_url  \
# 4                   44616               https://www.airbnb.com/rooms/44616
# 1524             15145820            https://www.airbnb.com/rooms/15145820
# 1855             15816189            https://www.airbnb.com/rooms/15816189
# 3269             21798352            https://www.airbnb.com/rooms/21798352
# 3452             22329567            https://www.airbnb.com/rooms/22329567
# ...                   ...                                              ...
# 23130  831143943749365415  https://www.airbnb.com/rooms/831143943749365415
# 23135  828266954841036561  https://www.airbnb.com/rooms/828266954841036561
# 23250  829074705000164647  https://www.airbnb.com/rooms/829074705000164647
# 23468  838377654302749381  https://www.airbnb.com/rooms/838377654302749381
# 23691  843085989518787496  https://www.airbnb.com/rooms/843085989518787496
#
#             scrape_id last_scraped       source  \
# ...

# %% [markdown]
# ## **g) Registros cuyo review scores cleanliness > 4.5**

# %% [markdown]
# ### California

# %%
calif['review_scores_cleanliness'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6936 entries, 0 to 6935
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 6936 non-null   float64
# dtypes: float64(1)
# memory usage: 54.3 KB

# %%
filtroG= calif['review_scores_cleanliness'] > 4.5
score1= calif[filtroG]
score1
# Out:
#              ï»¿id                                      listing_url  \
# 0     9.580000e+02                 https://www.airbnb.com/rooms/958
# 1     5.858000e+03                https://www.airbnb.com/rooms/5858
# 3     8.339000e+03                https://www.airbnb.com/rooms/8339
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# 5     1.421770e+05              https://www.airbnb.com/rooms/142177
# ...            ...                                              ...
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
# 6932  8.180000e+17  https://www.airbnb.com/rooms/818231243893035313
# 6933  8.180000e+17  https://www.airbnb.com/rooms/818396267693629070
# 6934  8.180000e+17  https://www.airbnb.com/rooms/818474518435984613
# 6935  8.190000e+17  https://www.airbnb.com/rooms/818887060432463897
#
#          scrape_id last_scraped       source  \
# 0     2.020000e+13   06/03/2023  city scrape
# 1     2.020000e+13   06/03/2023  city scrape
# ...

# %% [markdown]
# ### España

# %%
filtroG_e= esp['review_scores_cleanliness'] > 4.5
score2= esp[filtroG_e]
score2
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 1      1.205757e+06             https://www.airbnb.com/rooms/1205757
# 4      4.134200e+04               https://www.airbnb.com/rooms/41342
# 5      7.519970e+05              https://www.airbnb.com/rooms/751997
# 6      7.520350e+05              https://www.airbnb.com/rooms/752035
# ...             ...                                              ...
# 19650  8.583870e+17  https://www.airbnb.com/rooms/858386613168601750
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
# 19652  8.584110e+17  https://www.airbnb.com/rooms/858410917126332945
# 19653  8.584180e+17  https://www.airbnb.com/rooms/858418062773719271
# 19654  8.584240e+17  https://www.airbnb.com/rooms/858424461046143986
#
#           scrape_id last_scraped           source  \
# 0      2.023030e+13   31/03/2023      city scrape
# ...

# %% [markdown]
# ### México

# %%
filtroG_m= mex['review_scores_cleanliness'] > 4.5
score3= mex[filtroG_m]
score3
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %% [markdown]
# ## **h) Registros cuyo review_scores_value > 4.9**

# %% [markdown]
# ### California

# %%
filtroH= calif['review_scores_value'] > 4.9
val= calif[filtroH]
val
# Out:
#              ï»¿id                                      listing_url  \
# 9     1.442420e+05              https://www.airbnb.com/rooms/144242
# 24    1.491080e+05              https://www.airbnb.com/rooms/149108
# 26    1.252200e+04               https://www.airbnb.com/rooms/12522
# 46    5.308570e+05              https://www.airbnb.com/rooms/530857
# 53    5.616020e+05              https://www.airbnb.com/rooms/561602
# ...            ...                                              ...
# 6920  8.170000e+17  https://www.airbnb.com/rooms/816871631018815995
# 6924  8.170000e+17  https://www.airbnb.com/rooms/817017027613797792
# 6925  8.170000e+17  https://www.airbnb.com/rooms/817053637695588890
# 6927  8.170000e+17  https://www.airbnb.com/rooms/817390268252267687
# 6932  8.180000e+17  https://www.airbnb.com/rooms/818231243893035313
#
#          scrape_id last_scraped           source  \
# 9     2.020000e+13   06/03/2023      city scrape
# ...

# %% [markdown]
# ### España

# %%
filtroH_e= esp['review_scores_value'] > 4.9
val2= esp[filtroH_e]
val2
# Out:
#                  id                                      listing_url  \
# 22     1.234785e+06             https://www.airbnb.com/rooms/1234785
# 26     7.743710e+05              https://www.airbnb.com/rooms/774371
# 40     1.250062e+06             https://www.airbnb.com/rooms/1250062
# 43     8.091360e+05              https://www.airbnb.com/rooms/809136
# 53     1.262051e+06             https://www.airbnb.com/rooms/1262051
# ...             ...                                              ...
# 19038  8.413170e+17  https://www.airbnb.com/rooms/841316614411176358
# 19046  8.416740e+17  https://www.airbnb.com/rooms/841674432208362342
# 19077  8.419960e+17  https://www.airbnb.com/rooms/841995834617979068
# 19202  8.427110e+17  https://www.airbnb.com/rooms/842711402238569326
# 19467  8.500410e+17  https://www.airbnb.com/rooms/850040965563668557
#
#           scrape_id last_scraped       source  \
# 22     2.023030e+13   01/04/2023  city scrape
# ...

# %% [markdown]
# ### México

# %%
filtroH_m= mex['review_scores_value'] > 4.9
val3= mex[filtroH_m]
val3
# Out:
#                        id                                      listing_url  \
# 10                2083241             https://www.airbnb.com/rooms/2083241
# 11                  67703               https://www.airbnb.com/rooms/67703
# 13                  70644               https://www.airbnb.com/rooms/70644
# 24                 783080              https://www.airbnb.com/rooms/783080
# 26                2118573             https://www.airbnb.com/rooms/2118573
# ...                   ...                                              ...
# 24057  852767946409179558  https://www.airbnb.com/rooms/852767946409179558
# 24058  852783467088960077  https://www.airbnb.com/rooms/852783467088960077
# 24109  853066443231508045  https://www.airbnb.com/rooms/853066443231508045
# 24127  853138507789476424  https://www.airbnb.com/rooms/853138507789476424
# 24188  856097336186057624  https://www.airbnb.com/rooms/856097336186057624
#
#             scrape_id last_scraped       source  \
# ...

# %% [markdown]
# ## **i) Registros cuyo availability_365 < 100**

# %% [markdown]
# ### California

# %%
filtroI= calif['availability_365'] <100
C= calif[filtroI]
C
# Out:
#              ï»¿id                                      listing_url  \
# 5     1.421770e+05              https://www.airbnb.com/rooms/142177
# 8     4.918670e+05              https://www.airbnb.com/rooms/491867
# 9     1.442420e+05              https://www.airbnb.com/rooms/144242
# 11    1.449780e+05              https://www.airbnb.com/rooms/144978
# 15    5.017700e+05              https://www.airbnb.com/rooms/501770
# ...            ...                                              ...
# 6913  8.160000e+17  https://www.airbnb.com/rooms/815561340398335999
# 6917  8.160000e+17  https://www.airbnb.com/rooms/816028610191508453
# 6918  8.160000e+17  https://www.airbnb.com/rooms/816211107298614925
# 6923  8.170000e+17  https://www.airbnb.com/rooms/816998498709351546
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
#
#          scrape_id last_scraped           source  \
# 5     2.020000e+13   06/03/2023      city scrape
# ...

# %% [markdown]
# ### España

# %%
filtroI_e= esp['availability_365'] <100
E= esp[filtroI_e]
E
# Out:
#                  id                                      listing_url  \
# 4      4.134200e+04               https://www.airbnb.com/rooms/41342
# 7      1.215790e+06             https://www.airbnb.com/rooms/1215790
# 11     4.876400e+04               https://www.airbnb.com/rooms/48764
# 15     9.334300e+04               https://www.airbnb.com/rooms/93343
# 20     1.234784e+06             https://www.airbnb.com/rooms/1234784
# ...             ...                                              ...
# 19627  8.576760e+17  https://www.airbnb.com/rooms/857675856004912385
# 19632  8.577700e+17  https://www.airbnb.com/rooms/857770414483633162
# 19634  8.577820e+17  https://www.airbnb.com/rooms/857782451288614097
# 19638  8.578580e+17  https://www.airbnb.com/rooms/857858073918571632
# 19654  8.584240e+17  https://www.airbnb.com/rooms/858424461046143986
#
#           scrape_id last_scraped           source  \
# 4      2.023030e+13   01/04/2023  previous scrape
# ...

# %% [markdown]
# ### México

# %%
filtroI_m= mex['availability_365'] <100
M= mex[filtroI_m]
M
# Out:
#                        id                                      listing_url  \
# 2                  696037              https://www.airbnb.com/rooms/696037
# 21                 131610              https://www.airbnb.com/rooms/131610
# 26                2118573             https://www.airbnb.com/rooms/2118573
# 37                 187030              https://www.airbnb.com/rooms/187030
# 38                 187745              https://www.airbnb.com/rooms/187745
# ...                   ...                                              ...
# 24159  855707027566011822  https://www.airbnb.com/rooms/855707027566011822
# 24165  857302748334760420  https://www.airbnb.com/rooms/857302748334760420
# 24170  857303139403993330  https://www.airbnb.com/rooms/857303139403993330
# 24186  856096385840740213  https://www.airbnb.com/rooms/856096385840740213
# 24193  856446199505406242  https://www.airbnb.com/rooms/856446199505406242
#
#             scrape_id last_scraped           source  \
# ...

# %% [markdown]
# ## **j) Registros cuya host_response_time sea "within an hour"**

# %% [markdown]
# ### California

# %%
calif['host_response_time'].unique()
# Out:
# array(['within an hour', 'within a few hours', 'within a day',
#        'Sin registro', 'a few days or more'], dtype=object)

# %%
filtroJ= calif['host_response_time'] == 'within an hour'
time= calif[filtroJ]
time
# Out:
#              ï»¿id                                      listing_url  \
# 0     9.580000e+02                 https://www.airbnb.com/rooms/958
# 2     8.142000e+03                https://www.airbnb.com/rooms/8142
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# 5     1.421770e+05              https://www.airbnb.com/rooms/142177
# 12    4.938890e+05              https://www.airbnb.com/rooms/493889
# ...            ...                                              ...
# 6929  8.180000e+17  https://www.airbnb.com/rooms/817686120681200035
# 6930  8.180000e+17  https://www.airbnb.com/rooms/818185441952600448
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
# 6934  8.180000e+17  https://www.airbnb.com/rooms/818474518435984613
# 6935  8.190000e+17  https://www.airbnb.com/rooms/818887060432463897
#
#          scrape_id last_scraped       source  \
# 0     2.020000e+13   06/03/2023  city scrape
# 2     2.020000e+13   06/03/2023  city scrape
# ...

# %% [markdown]
# ### España

# %%
filtroJ_e= esp['host_response_time'] == 'within an hour'
time2= esp[filtroJ_e]
time2
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 5      7.519970e+05              https://www.airbnb.com/rooms/751997
# 6      7.520350e+05              https://www.airbnb.com/rooms/752035
# 8      4.540000e+04               https://www.airbnb.com/rooms/45400
# 10     7.536040e+05              https://www.airbnb.com/rooms/753604
# ...             ...                                              ...
# 19647  8.583550e+17  https://www.airbnb.com/rooms/858355485916277793
# 19648  8.583610e+17  https://www.airbnb.com/rooms/858361225190866263
# 19650  8.583870e+17  https://www.airbnb.com/rooms/858386613168601750
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
# 19653  8.584180e+17  https://www.airbnb.com/rooms/858418062773719271
#
#           scrape_id last_scraped       source  \
# 0      2.023030e+13   31/03/2023  city scrape
# ...

# %% [markdown]
# ### México

# %%
filtroJ_m= mex['host_response_time'] == 'within an hour'
time3= mex[filtroJ_m]
time3
# Out:
#                        id                                      listing_url  \
# 2                  696037              https://www.airbnb.com/rooms/696037
# 4                   44616               https://www.airbnb.com/rooms/44616
# 6                   56074               https://www.airbnb.com/rooms/56074
# 7                   61792               https://www.airbnb.com/rooms/61792
# 8                  704779              https://www.airbnb.com/rooms/704779
# ...                   ...                                              ...
# 24214  853724742831978094  https://www.airbnb.com/rooms/853724742831978094
# 24216  853779337045988604  https://www.airbnb.com/rooms/853779337045988604
# 24217  853790308958785669  https://www.airbnb.com/rooms/853790308958785669
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
#
#             scrape_id last_scraped       source  \
# ...

# %% [markdown]
# ## Descargas

# %%
#Inciso a
  #California
filtroA.to_csv("FiltroA_california.csv")
from google.colab import files 
files.download("FiltroA_california.csv")

  #Girona
filtroA_e.to_csv("FiltroA_españa.csv")
from google.colab import files 
files.download("FiltroA_españa.csv")

  #México
filtroA_m.to_csv("FiltroA_mex.csv")
from google.colab import files 
files.download("FiltroA_mex.csv")

# %%
#Inciso b
  #California
filtroB.to_csv("FiltroB_california.csv")
from google.colab import files 
files.download("FiltroB_california.csv")

  #Girona
filtroB_e.to_csv("FiltroB_españa.csv")
from google.colab import files 
files.download("FiltroB_españa.csv")

  #México
filtroB_m.to_csv("FiltroB_mex.csv")
from google.colab import files 
files.download("FiltroB_mex.csv")

# %%
#Inciso c
  #California
filtroC.to_csv("FiltroC_california.csv")
from google.colab import files 
files.download("FiltroC_california.csv")

  #Girona
filtroC_e.to_csv("FiltroC_españa.csv")
from google.colab import files 
files.download("FiltroC_españa.csv")

  #México
filtroC_m.to_csv("FiltroC_mex.csv")
from google.colab import files 
files.download("FiltroC_mex.csv")

# %%
#Inciso d
  #California
property_c.to_csv("FiltroD_california.csv")
from google.colab import files 
files.download("FiltroD_california.csv")

  #Girona
property_e.to_csv("FiltroD_españa.csv")
from google.colab import files 
files.download("FiltroD_españa.csv")

  #México
property_m.to_csv("FiltroD_mex.csv")
from google.colab import files 
files.download("FiltroD_mex.csv")

# %%
#Inciso e
  #California
baths_c.to_csv("FiltroE_california.csv")
from google.colab import files 
files.download("FiltroE_california.csv")

  #Girona
baths_e.to_csv("FiltroE_españa.csv")
from google.colab import files 
files.download("FiltroE_españa.csv")

  #México
baths_m.to_csv("FiltroE_mex.csv")
from google.colab import files 
files.download("FiltroE_mex.csv")

# %%
#Inciso f
  #California
df1.to_csv("FiltroF_california.csv")
from google.colab import files 
files.download("FiltroF_california.csv")

  #Girona
df2.to_csv("FiltroF_españa.csv")
from google.colab import files 
files.download("FiltroF_españa.csv")

  #México
df3.to_csv("FiltroF_mex.csv")
from google.colab import files 
files.download("FiltroF_mex.csv")

# %%
#Inciso g
  #California
score1.to_csv("FiltroG_california.csv")
from google.colab import files 
files.download("FiltroG_california.csv")

  #Girona
score2.to_csv("FiltroG_españa.csv")
from google.colab import files 
files.download("FiltroG_españa.csv")

  #México
score3.to_csv("FiltroG_mex.csv")
from google.colab import files 
files.download("FiltroG_mex.csv")

# %%
#Inciso h
  #California
val.to_csv("FiltroH_california.csv")
from google.colab import files 
files.download("FiltroH_california.csv")

  #Girona
val2.to_csv("FiltroH_españa.csv")
from google.colab import files 
files.download("FiltroH_españa.csv")

  #México
val3.to_csv("FiltroH_mex.csv")
from google.colab import files 
files.download("FiltroH_mex.csv")

# %%
#Inciso i
  #California
C.to_csv("FiltroI_california.csv")
from google.colab import files 
files.download("FiltroI_california.csv")

  #Girona
E.to_csv("FiltroI_españa.csv")
from google.colab import files 
files.download("FiltroI_españa.csv")

  #México
M.to_csv("FiltroI_mex.csv")
from google.colab import files 
files.download("FiltroI_mex.csv")

# %%
#Inciso j
  #California
time.to_csv("FiltroJ_california.csv")
from google.colab import files 
files.download("FiltroJ_california.csv")

  #Girona
time2.to_csv("FiltroJ_españa.csv")
from google.colab import files 
files.download("FiltroJ_españa.csv")

  #México
time3.to_csv("FiltroJ_mex.csv")
from google.colab import files 
files.download("FiltroJ_mex.csv")

# %% [markdown]
# # **Etapa 3**

# %%
# !pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
calif['bathrooms_text'] = calif['bathrooms_text'].astype('object')

# %%
calif_5 = calif[['host_response_time', 'host_identity_verified', 'property_type', 'bathrooms_text', 'host_acceptance_rate']]
calif_5
# Out:
#       host_response_time host_identity_verified                property_type  \
# 0         within an hour                      t    Entire serviced apartment
# 1     within a few hours                      t           Entire rental unit
# 2         within an hour                      t  Private room in rental unit
# 3     within a few hours                      t                 Entire condo
# 4         within an hour                      t        Private room in condo
# ...                  ...                    ...                          ...
# 6931      within an hour                      f           Entire rental unit
# 6932        Sin registro                      f           Entire rental unit
# 6933        Sin registro                      f  Private room in rental unit
# 6934      within an hour                      t         Private room in home
# 6935      within an hour                      t           Entire rental unit
#
#      bathrooms_text  host_acceptance_rate
# ...

# %%
calif['bathrooms_text'].unique()
# Out:
# array([1.0, 4.0, 2.0, 0.0, 3.0, 10.0, 5.0, 8.0, 6.0], dtype=object)

# %%
esp_5 = esp[['host_response_time', 'host_identity_verified', 'property_type', 'bathrooms_text', 'host_acceptance_rate']]
esp_5
# Out:
#        host_response_time host_identity_verified  \
# 0          within an hour                      t
# 1            within a day                      t
# 2            within a day                      f
# 3      within a few hours                      t
# 4            Sin registro                      t
# ...                   ...                    ...
# 19650      within an hour                      t
# 19651      within an hour                      t
# 19652  a few days or more                      t
# 19653      within an hour                      t
# 19654  a few days or more                      t
#
#                            property_type  bathrooms_text  host_acceptance_rate
# 0                  Private room in condo             1.0                    90
# 1                   Private room in loft             1.0                    42
# 2                           Entire condo             1.0                    80
# ...

# %%
mex_5 = mex[['host_response_time', 'host_identity_verified', 'property_type', 'bathrooms_text', 'host_acceptance_rate']]
mex_5
# Out:
#       host_response_time host_identity_verified         property_type  \
# 0           within a day                      f           Entire loft
# 1           Sin registro                      t    Entire guest suite
# 2         within an hour                      t    Entire rental unit
# 3           Sin registro                      t          Entire villa
# 4         within an hour                      t           Entire home
# ...                  ...                    ...                   ...
# 24219     within an hour                      t    Entire rental unit
# 24220       Sin registro                      t    Entire rental unit
# 24221       Sin registro                      t  Private room in home
# 24222     within an hour                      t    Entire rental unit
# 24223       Sin registro                      t    Entire rental unit
#
#        bathrooms_text  host_acceptance_rate
# 0                 1.0                     0
# ...

# %% [markdown]
# ## **Host_response_time**

# %% [markdown]
# ### California

# %%
table1= freq_tbl(calif_5['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       4221    0.608564         0.608564
# 1  within a few hours       1111    0.160179         0.768743
# 2        Sin registro       1019    0.146915         0.915657
# 3        within a day        452    0.065167         0.980825
# 4  a few days or more        133    0.019175         1.000000

# %%
tabla1= table1.set_index('host_response_time')
tabla1['frequency'].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### España

# %%
table2= freq_tbl(esp_5['host_response_time'])
table2
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      12261    0.623811         0.623811
# 1  within a few hours       2700    0.137370         0.761180
# 2        within a day       2188    0.111320         0.872501
# 3        Sin registro       2088    0.106233         0.978733
# 4  a few days or more        418    0.021267         1.000000

# %%
tabla2= table2.set_index('host_response_time')
tabla2['frequency'].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### México

# %%
table3= freq_tbl(mex_5['host_response_time'])
table3
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      16997    0.701660         0.701660
# 1        Sin registro       3091    0.127601         0.829260
# 2  within a few hours       1966    0.081159         0.910419
# 3        within a day       1450    0.059858         0.970277
# 4  a few days or more        720    0.029723         1.000000

# %%
tabla3= table3.set_index('host_response_time')
tabla3['frequency'].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## **host_identity_verified**

# %% [markdown]
# ### California

# %%
table4= freq_tbl(calif_5['host_identity_verified'])
table4
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       6106    0.880334         0.880334
# 1                      f        830    0.119666         1.000000

# %%
tabla4= table4.set_index('host_identity_verified')
tabla4['frequency'].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### España

# %%
table5= freq_tbl(esp_5['host_identity_verified'])
table5
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      17277    0.879013         0.879013
# 1                      f       2261    0.115034         0.994047
# 2           Sin registro        117    0.005953         1.000000

# %%
tabla5= table5.set_index('host_identity_verified')
tabla5['frequency'].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### México

# %%
table6= freq_tbl(mex_5['host_identity_verified'])
table6
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      22301    0.920616         0.920616
# 1                      f       1923    0.079384         1.000000

# %%
tabla6= table6.set_index('host_identity_verified')
tabla6['frequency'].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## **property_type**

# %% [markdown]
# ### California

# %%
table7= freq_tbl(calif_5['property_type'])
table7
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       1848    0.266436         0.266436
# 1                         Entire condo        879    0.126730         0.393166
# 2                 Private room in home        853    0.122982         0.516148
# 3                          Entire home        839    0.120963         0.637111
# 4                   Entire guest suite        495    0.071367         0.708478
# 5          Private room in rental unit        471    0.067907         0.776384
# 6               Room in boutique hotel        352    0.050750         0.827134
# 7                        Room in hotel        265    0.038206         0.865340
# 8                Private room in condo        192    0.027682         0.893022
# 9            Entire serviced apartment        145    0.020905         0.913927
# 10                  Room in aparthotel         68    0.009804         0.923731
# ...

# %%
f= table7[table7['frequency']>=60]
f
# Out:
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       1848    0.266436         0.266436
# 1                  Entire condo        879    0.126730         0.393166
# 2          Private room in home        853    0.122982         0.516148
# 3                   Entire home        839    0.120963         0.637111
# 4            Entire guest suite        495    0.071367         0.708478
# 5   Private room in rental unit        471    0.067907         0.776384
# 6        Room in boutique hotel        352    0.050750         0.827134
# 7                 Room in hotel        265    0.038206         0.865340
# 8         Private room in condo        192    0.027682         0.893022
# 9     Entire serviced apartment        145    0.020905         0.913927
# 10           Room in aparthotel         68    0.009804         0.923731
# 11             Entire townhouse         63    0.009083         0.932814
# ...

# %%
tabla7=f.set_index('property_type')
tabla7.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipo de propiedad (California)')
#plt.xlabel('Aparato')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### España

# %%
table8= freq_tbl(esp_5['property_type'])
table8
# Out:
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       9339    0.475146         0.475146
# 1                   Entire home       3703    0.188400         0.663546
# 2                  Entire villa       1715    0.087255         0.750801
# 3                  Entire condo       1400    0.071229         0.822030
# 4                Entire cottage        549    0.027932         0.849962
# ..                          ...        ...         ...              ...
# 72                        Floor          1    0.000051         0.999796
# 73       Shared room in cottage          1    0.000051         0.999847
# 74  Shared room in nature lodge          1    0.000051         0.999898
# 75      Private room in pension          1    0.000051         0.999949
# 76     Entire bed and breakfast          1    0.000051         1.000000
#
# [77 rows x 4 columns]

# %%
f= table8[table8['frequency']>160]
f
# Out:
#                         property_type  frequency  percentage  cumulative_perc
# 0                  Entire rental unit       9339    0.475146         0.475146
# 1                         Entire home       3703    0.188400         0.663546
# 2                        Entire villa       1715    0.087255         0.750801
# 3                        Entire condo       1400    0.071229         0.822030
# 4                      Entire cottage        549    0.027932         0.849962
# 5                    Entire townhouse        453    0.023048         0.873009
# 6                         Entire loft        217    0.011040         0.884050
# 7                       Room in hotel        184    0.009361         0.893411
# 8   Private room in bed and breakfast        179    0.009107         0.902518
# 9           Entire serviced apartment        175    0.008904         0.911422
# 10        Private room in rental unit        172    0.008751         0.920173
# ...

# %%
tabla8=f.set_index('property_type')
tabla8.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipo de propiedad (Girona)')
#plt.xlabel('Aparato')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### México

# %%
table9= freq_tbl(mex_5['property_type'])
table9
# Out:
#                    property_type  frequency  percentage  cumulative_perc
# 0             Entire rental unit       8145    0.336237         0.336237
# 1                   Entire condo       3363    0.138829         0.475066
# 2    Private room in rental unit       2860    0.118065         0.593131
# 3           Private room in home       2009    0.082934         0.676065
# 4                    Entire loft       1584    0.065390         0.741455
# ..                           ...        ...         ...              ...
# 87                 Entire in-law          1    0.000041         0.999835
# 88          Private room in barn          1    0.000041         0.999876
# 89      Shared room in tiny home          1    0.000041         0.999917
# 90  Private room in earthen home          1    0.000041         0.999959
# 91           Shared room in tent          1    0.000041         1.000000
#
# [92 rows x 4 columns]

# %%
f= table9[table9['frequency']>245]
f
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       8145    0.336237         0.336237
# 1                         Entire condo       3363    0.138829         0.475066
# 2          Private room in rental unit       2860    0.118065         0.593131
# 3                 Private room in home       2009    0.082934         0.676065
# 4                          Entire loft       1584    0.065390         0.741455
# 5            Entire serviced apartment       1067    0.044047         0.785502
# 6                Private room in condo        917    0.037855         0.823357
# 7                          Entire home        661    0.027287         0.850644
# 8                        Room in hotel        381    0.015728         0.866372
# 9          Private room in guest suite        297    0.012261         0.878633
# 10  Private room in serviced apartment        295    0.012178         0.890811
# ...

# %%
tabla9=f.set_index('property_type')
tabla9.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipo de propiedad (DF)')
#plt.xlabel('Aparato')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## **bathrooms_text**

# %% [markdown]
# ### California

# %%
calif2 = pd.read_csv('California_EUA (1).csv',encoding='unicode_escape')

# %%
C_bath = calif2['bathrooms_text']
C_bath
# Out:
# 0               1 bath
# 1               1 bath
# 2       4 shared baths
# 3            1.5 baths
# 4       1 private bath
#              ...
# 6931            1 bath
# 6932            1 bath
# 6933     1 shared bath
# 6934     1 shared bath
# 6935            1 bath
# Name: bathrooms_text, Length: 6936, dtype: object

# %%
table10= freq_tbl(calif2['bathrooms_text'])
table10
# Out:
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       3329    0.479960         0.480930
# 1      1 private bath       1013    0.146050         0.627275
# 2             2 baths        844    0.121684         0.749205
# 3       1 shared bath        675    0.097318         0.846721
# 4           1.5 baths        290    0.041811         0.888616
# 5    1.5 shared baths        141    0.020329         0.908986
# 6           2.5 baths        128    0.018454         0.927478
# 7             3 baths        122    0.017589         0.945103
# 8      2 shared baths         85    0.012255         0.957382
# 9      5 shared baths         63    0.009083         0.966484
# 10          3.5 baths         36    0.005190         0.971684
# 11     0 shared baths         25    0.003604         0.975296
# 12            4 baths         23    0.003316         0.978619
# 13     3 shared baths         22    0.003172         0.981797
# ...

# %%
f= table10[table10['frequency']>20]
f
# Out:
#       bathrooms_text  frequency  percentage  cumulative_perc
# 0             1 bath       3329    0.479960         0.480930
# 1     1 private bath       1013    0.146050         0.627275
# 2            2 baths        844    0.121684         0.749205
# 3      1 shared bath        675    0.097318         0.846721
# 4          1.5 baths        290    0.041811         0.888616
# 5   1.5 shared baths        141    0.020329         0.908986
# 6          2.5 baths        128    0.018454         0.927478
# 7            3 baths        122    0.017589         0.945103
# 8     2 shared baths         85    0.012255         0.957382
# 9     5 shared baths         63    0.009083         0.966484
# 10         3.5 baths         36    0.005190         0.971684
# 11    0 shared baths         25    0.003604         0.975296
# 12           4 baths         23    0.003316         0.978619
# 13    3 shared baths         22    0.003172         0.981797
# ...

# %%
tabla10=f.set_index('bathrooms_text')
tabla10.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Catidad de baños (California)')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### España

# %%
esp2 = pd.read_csv('Girona_Espana.csv', encoding='unicode_escape')

# %%
table11= freq_tbl(esp2['bathrooms_text'])
table11
# Out:
#       bathrooms_text  frequency  percentage  cumulative_perc
# 0             1 bath       9648    0.490867         0.491267
# 1            2 baths       4618    0.234953         0.726412
# 2            3 baths       1245    0.063343         0.789806
# 3          1.5 baths       1180    0.060036         0.849891
# 4          2.5 baths        648    0.032969         0.882886
# 5     1 private bath        564    0.028695         0.911604
# 6            4 baths        433    0.022030         0.933652
# 7          3.5 baths        260    0.013228         0.946891
# 8      1 shared bath        252    0.012821         0.959723
# 9            5 baths        159    0.008090         0.967819
# 10         4.5 baths        133    0.006767         0.974591
# 11           6 baths         78    0.003968         0.978563
# 12  1.5 shared baths         76    0.003867         0.982433
# 13         5.5 baths         53    0.002697         0.985132
# ...

# %%
f= table11[table11['frequency']>38]
f
# Out:
#       bathrooms_text  frequency  percentage  cumulative_perc
# 0             1 bath       9648    0.490867         0.491267
# 1            2 baths       4618    0.234953         0.726412
# 2            3 baths       1245    0.063343         0.789806
# 3          1.5 baths       1180    0.060036         0.849891
# 4          2.5 baths        648    0.032969         0.882886
# 5     1 private bath        564    0.028695         0.911604
# 6            4 baths        433    0.022030         0.933652
# 7          3.5 baths        260    0.013228         0.946891
# 8      1 shared bath        252    0.012821         0.959723
# 9            5 baths        159    0.008090         0.967819
# 10         4.5 baths        133    0.006767         0.974591
# 11           6 baths         78    0.003968         0.978563
# 12  1.5 shared baths         76    0.003867         0.982433
# 13         5.5 baths         53    0.002697         0.985132
# ...

# %%
tabla11=f.set_index('bathrooms_text')
tabla11.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Catidad de baños (España)')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### México

# %%
mex2 = pd.read_csv('DF_Mexico.csv')

# %%
table12= freq_tbl(mex2['bathrooms_text'])
table12
# Out:
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       9139    0.377270         0.377738
# 1             2 baths       4203    0.173506         0.551459
# 2      1 private bath       3242    0.133834         0.685459
# 3       1 shared bath       2834    0.116991         0.802596
# 4           1.5 baths       1395    0.057588         0.860255
# 5           2.5 baths        858    0.035419         0.895718
# 6    1.5 shared baths        614    0.025347         0.921096
# 7             3 baths        458    0.018907         0.940026
# 8      2 shared baths        307    0.012673         0.952716
# 9           3.5 baths        248    0.010238         0.962966
# 10   2.5 shared baths        151    0.006233         0.969207
# 11            4 baths        127    0.005243         0.974456
# 12     3 shared baths        110    0.004541         0.979003
# 13          4.5 baths         96    0.003963         0.982971
# ...

# %%
f= table12[table12['frequency']>95]
f
# Out:
#       bathrooms_text  frequency  percentage  cumulative_perc
# 0             1 bath       9139    0.377270         0.377738
# 1            2 baths       4203    0.173506         0.551459
# 2     1 private bath       3242    0.133834         0.685459
# 3      1 shared bath       2834    0.116991         0.802596
# 4          1.5 baths       1395    0.057588         0.860255
# 5          2.5 baths        858    0.035419         0.895718
# 6   1.5 shared baths        614    0.025347         0.921096
# 7            3 baths        458    0.018907         0.940026
# 8     2 shared baths        307    0.012673         0.952716
# 9          3.5 baths        248    0.010238         0.962966
# 10  2.5 shared baths        151    0.006233         0.969207
# 11           4 baths        127    0.005243         0.974456
# 12    3 shared baths        110    0.004541         0.979003
# 13         4.5 baths         96    0.003963         0.982971

# %%
tabla12=f.set_index('bathrooms_text')
tabla12.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Catidad de baños (México)')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## host_acceptace_rate

# %% [markdown]
# ### California

# %%
HA = calif2['host_acceptance_rate']

# %%
table13= freq_tbl(calif2['host_acceptance_rate'])
table13
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       2252    0.324683         0.367074
# 1                   99%        540    0.077855         0.455094
# 2                   97%        451    0.065023         0.528606
# 3                   98%        258    0.037197         0.570660
# 4                   91%        216    0.031142         0.605868
# ..                  ...        ...         ...              ...
# 81                  27%          2    0.000288         0.999185
# 82                  22%          2    0.000288         0.999511
# 83                  48%          1    0.000144         0.999674
# 84                  21%          1    0.000144         0.999837
# 85                  45%          1    0.000144         1.000000
#
# [86 rows x 4 columns]

# %%
f= table13[table13['frequency']>100]
f
# Out:
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                 100%       2252    0.324683         0.367074
# 1                  99%        540    0.077855         0.455094
# 2                  97%        451    0.065023         0.528606
# 3                  98%        258    0.037197         0.570660
# 4                  91%        216    0.031142         0.605868
# 5                  96%        158    0.022780         0.631622
# 6                  95%        143    0.020617         0.654931
# 7                  94%        138    0.019896         0.677425
# 8                   0%        121    0.017445         0.697148

# %% [markdown]
# ### España

# %%
HA_e = esp2['host_acceptance_rate']

# %%
table14= freq_tbl(esp2['host_acceptance_rate'])
table14
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       7478    0.380463         0.404173
# 1                   99%       2221    0.112999         0.524214
# 2                   98%       1049    0.053371         0.580910
# 3                   96%        753    0.038311         0.621608
# 4                   97%        735    0.037395         0.661334
# ..                  ...        ...         ...              ...
# 86                  18%          1    0.000051         0.999784
# 87                  23%          1    0.000051         0.999838
# 88                   7%          1    0.000051         0.999892
# 89                  21%          1    0.000051         0.999946
# 90                   8%          1    0.000051         1.000000
#
# [91 rows x 4 columns]

# %%
f= table14[table14['frequency']>225]
f
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       7478    0.380463         0.404173
# 1                   99%       2221    0.112999         0.524214
# 2                   98%       1049    0.053371         0.580910
# 3                   96%        753    0.038311         0.621608
# 4                   97%        735    0.037395         0.661334
# 5                   91%        518    0.026355         0.689331
# 6                    0%        407    0.020707         0.711329
# 7                   89%        391    0.019893         0.732461
# 8                   95%        291    0.014805         0.748189
# 9                   94%        267    0.013584         0.762620
# 10                  93%        233    0.011854         0.775213

# %% [markdown]
# ### México

# %%
table15= freq_tbl(mex2['host_acceptance_rate'])
table15
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%      11617    0.479566         0.523737
# 1                   99%       2704    0.111625         0.645643
# 2                   98%       1031    0.042561         0.692124
# 3                   97%        711    0.029351         0.724178
# 4                    0%        701    0.028938         0.755782
# ..                  ...        ...         ...              ...
# 85                  34%          2    0.000083         0.999820
# 86                  13%          1    0.000041         0.999865
# 87                   9%          1    0.000041         0.999910
# 88                  18%          1    0.000041         0.999955
# 89                  30%          1    0.000041         1.000000
#
# [90 rows x 4 columns]

# %%
f= table15[table15['frequency']>210]
f
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%      11617    0.479566         0.523737
# 1                   99%       2704    0.111625         0.645643
# 2                   98%       1031    0.042561         0.692124
# 3                   97%        711    0.029351         0.724178
# 4                    0%        701    0.028938         0.755782
# 5                   96%        575    0.023737         0.781705
# 6                   94%        430    0.017751         0.801091
# 7                   93%        279    0.011518         0.813669
# 8                   92%        268    0.011063         0.825752
# 9                   95%        264    0.010898         0.837654
# 10                  50%        233    0.009619         0.848158
